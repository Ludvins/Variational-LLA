# %% [markdown]
# # Data Collection

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import glob
import pandas as pd

os.chdir(".")
res1 = [i for i in glob.glob("results/MAP_dataset=*[!fixed_prior]")]
df = []
for f in res1:
    try:
        df.append(pd.read_csv(f))
    except:
        continue
MAP = pd.concat(df)


res1 = [i for i in glob.glob("results/LLA_dataset=*[!fixed_prior]")]
df = []
for f in res1:
    try:
        df.append(pd.read_csv(f))
    except:
        continue
LLA = pd.concat(df)


res1 = [i for i in glob.glob("results/ELLA_dataset=*[!fixed_prior]")]
df = []
for f in res1:
    try:
        df.append(pd.read_csv(f))
    except:
        continue
ELLA = pd.concat(df)

# %%
min_value = ELLA.groupby(["M", "dataset", "seed"])["val_NLL"].min()
ELLA_min = ELLA.merge(min_value, on=["M", "dataset", "seed"], suffixes=('', '_min'))
ELLA_min = ELLA_min.query("val_NLL == val_NLL_min")
#print(indices_min_nll)
#ELLA_max = ELLA.loc[indices_min_nll]
ELLA_min = ELLA_min.groupby(["M", "dataset", "seed"]).first().reset_index()
ELLA_min = ELLA_min.drop("val_NLL_min", axis = 1)

# %%
res1 = [i for i in glob.glob("results/VaLLA_dataset*[!fixed_prior]")]
df = []
for f in res1:
    try:
        df.append(pd.read_csv(f))
    except:
        continue
VaLLA = pd.concat(df)


def std(x):
    return np.std(x) / np.sqrt(len(x))


VaLLA["model"] = "VaLLA"
MAP["model"] = "MAP"
ELLA_min["model"] = "ELLA"
LLA["model"] = "LLA"

df = pd.concat([MAP, LLA, ELLA_min, VaLLA]).drop(
    ["LOSS", "Unnamed: 0", "iterations", "weight_decay", "MAP_iterations"], axis=1
)
# Out:
# /tmp/ipykernel_114841/1351975395.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   MAP["model"] = "MAP"

# %%
regression = df[df["dataset"].isin(["Year", "Airline", "Taxi"])]
multiclass = df[~df["dataset"].isin(["Year", "Airline", "Taxi"])]
regression = regression.dropna(axis = 1, how = 'all')
multiclass = multiclass.dropna(axis = 1, how = 'all')

# %%
Q = np.array([np.zeros_like(np.abs(regression["Q-10"]-0.1)), 
              np.abs(regression["Q-10"]-0.1).to_numpy(), 
              np.abs(regression["Q-20"]-0.2).to_numpy(), 
              np.abs(regression["Q-30"]-0.3).to_numpy(), 
              np.abs(regression["Q-40"]-0.4).to_numpy(), 
              np.abs(regression["Q-50"]-0.5).to_numpy(), 
              np.abs(regression["Q-60"]-0.6).to_numpy(), 
              np.abs(regression["Q-70"]-0.7).to_numpy(), 
              np.abs(regression["Q-80"]-0.8).to_numpy(), 
              np.abs(regression["Q-90"]-0.9).to_numpy(),
              np.ones_like(np.abs(regression["Q-10"]-0.1))
              ]).T

# %%
import scipy as sp
Q = sp.integrate.trapezoid(x = np.arange(0, 1.1, 0.1), y= Q, axis = 1)
regression["Q"] = Q

# %%
# df = df.astype({"M": "int"})
regression = regression.groupby(["dataset", "model","M", "subset", "hessian"], dropna=False).agg(["mean", std])
regression = regression.drop(["seed", "val_NLL", "log_variance", "alpha"], axis = 1)
regression = regression.drop(("RMSE", "std"),axis = 1)
regression = regression.dropna(axis = 1, how = 'all')

# %%
multiclass = multiclass.groupby(["dataset", "model","M", "subset", "hessian", "alpha"], dropna=False).agg(["mean", std])
multiclass = multiclass.drop(["seed", "val_NLL"], axis = 1)
multiclass = multiclass.dropna(axis = 1, how = 'all')

# %% [markdown]
# # Regression Fully Connected 200-200-200

# %% [markdown]
# ## Trainable / Validated Prior

# %% [markdown]
# #### Airline

# %%
subset =  [("RMSE", "mean"), ("NLL", "mean"),
           ("CRPS", "mean"), ("Q", "mean"),]

Q_columns = ["Q-10", "Q-20", "Q-30", "Q-40", "Q-50", "Q-60", "Q-70", "Q-80", "Q-90"]
regression.query("dataset == 'Airline'").drop(Q_columns, axis = 1).reset_index().style.background_gradient(axis=0, subset = subset)
# Out:
# <style type="text/css">
# #T_97be0_row0_col5, #T_97be0_row1_col5, #T_97be0_row2_col5, #T_97be0_row2_col8, #T_97be0_row3_col5, #T_97be0_row3_col8, #T_97be0_row4_col5, #T_97be0_row4_col8, #T_97be0_row5_col5, #T_97be0_row5_col8, #T_97be0_row6_col5, #T_97be0_row7_col5, #T_97be0_row8_col5, #T_97be0_row8_col6, #T_97be0_row8_col14 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_97be0_row0_col6, #T_97be0_row6_col6 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_97be0_row0_col8 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_97be0_row0_col14, #T_97be0_row1_col6, #T_97be0_row2_col6, #T_97be0_row3_col6, #T_97be0_row4_col6, #T_97be0_row5_col6, #T_97be0_row6_col14, #T_97be0_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_97be0_row1_col8 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_97be0_row1_col14 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_97be0_row2_col14, #T_97be0_row3_col14, #T_97be0_row4_col14, #T_97be0_row5_col14 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_97be0_row6_col8 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_97be0_row7_col6 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_97be0_row7_col8 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_97be0_row7_col14 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# </style>
# <table id="T_97be0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97be0_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_97be0_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_97be0_level0_col2" class="col_heading level0 col2" >M</th>
#       <th id="T_97be0_level0_col3" class="col_heading level0 col3" >subset</th>
#       <th id="T_97be0_level0_col4" class="col_heading level0 col4" >hessian</th>
#       <th id="T_97be0_level0_col5" class="col_heading level0 col5" >RMSE</th>
#       <th id="T_97be0_level0_col6" class="col_heading level0 col6" colspan="2">NLL</th>
#       <th id="T_97be0_level0_col8" class="col_heading level0 col8" colspan="2">CRPS</th>
#       <th id="T_97be0_level0_col10" class="col_heading level0 col10" colspan="2">time</th>
#       <th id="T_97be0_level0_col12" class="col_heading level0 col12" colspan="2">prior_std</th>
#       <th id="T_97be0_level0_col14" class="col_heading level0 col14" colspan="2">Q</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_97be0_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_97be0_level1_col1" class="col_heading level1 col1" ></th>
#       <th id="T_97be0_level1_col2" class="col_heading level1 col2" ></th>
#       <th id="T_97be0_level1_col3" class="col_heading level1 col3" ></th>
#       <th id="T_97be0_level1_col4" class="col_heading level1 col4" ></th>
#       <th id="T_97be0_level1_col5" class="col_heading level1 col5" >mean</th>
#       <th id="T_97be0_level1_col6" class="col_heading level1 col6" >mean</th>
#       <th id="T_97be0_level1_col7" class="col_heading level1 col7" >std</th>
#       <th id="T_97be0_level1_col8" class="col_heading level1 col8" >mean</th>
#       <th id="T_97be0_level1_col9" class="col_heading level1 col9" >std</th>
#       <th id="T_97be0_level1_col10" class="col_heading level1 col10" >mean</th>
#       <th id="T_97be0_level1_col11" class="col_heading level1 col11" >std</th>
#       <th id="T_97be0_level1_col12" class="col_heading level1 col12" >mean</th>
#       <th id="T_97be0_level1_col13" class="col_heading level1 col13" >std</th>
#       <th id="T_97be0_level1_col14" class="col_heading level1 col14" >mean</th>
#       <th id="T_97be0_level1_col15" class="col_heading level1 col15" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97be0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97be0_row0_col0" class="data row0 col0" >Airline</td>
#       <td id="T_97be0_row0_col1" class="data row0 col1" >ELLA</td>
#       <td id="T_97be0_row0_col2" class="data row0 col2" >2000.000000</td>
#       <td id="T_97be0_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_97be0_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_97be0_row0_col5" class="data row0 col5" >38.902980</td>
#       <td id="T_97be0_row0_col6" class="data row0 col6" >5.086446</td>
#       <td id="T_97be0_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_97be0_row0_col8" class="data row0 col8" >18.437332</td>
#       <td id="T_97be0_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_97be0_row0_col10" class="data row0 col10" >374.936004</td>
#       <td id="T_97be0_row0_col11" class="data row0 col11" >40.730871</td>
#       <td id="T_97be0_row0_col12" class="data row0 col12" >0.100000</td>
#       <td id="T_97be0_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_97be0_row0_col14" class="data row0 col14" >0.158029</td>
#       <td id="T_97be0_row0_col15" class="data row0 col15" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_97be0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97be0_row1_col0" class="data row1 col0" >Airline</td>
#       <td id="T_97be0_row1_col1" class="data row1 col1" >LLA</td>
#       <td id="T_97be0_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_97be0_row1_col3" class="data row1 col3" >all</td>
#       <td id="T_97be0_row1_col4" class="data row1 col4" >diag</td>
#       <td id="T_97be0_row1_col5" class="data row1 col5" >38.902980</td>
#       <td id="T_97be0_row1_col6" class="data row1 col6" >5.096887</td>
#       <td id="T_97be0_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_97be0_row1_col8" class="data row1 col8" >18.318920</td>
#       <td id="T_97be0_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_97be0_row1_col10" class="data row1 col10" >489.545136</td>
#       <td id="T_97be0_row1_col11" class="data row1 col11" >39.818773</td>
#       <td id="T_97be0_row1_col12" class="data row1 col12" >0.100413</td>
#       <td id="T_97be0_row1_col13" class="data row1 col13" >0.000000</td>
#       <td id="T_97be0_row1_col14" class="data row1 col14" >0.145234</td>
#       <td id="T_97be0_row1_col15" class="data row1 col15" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_97be0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_97be0_row2_col0" class="data row2 col0" >Airline</td>
#       <td id="T_97be0_row2_col1" class="data row2 col1" >LLA</td>
#       <td id="T_97be0_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_97be0_row2_col3" class="data row2 col3" >all</td>
#       <td id="T_97be0_row2_col4" class="data row2 col4" >kron</td>
#       <td id="T_97be0_row2_col5" class="data row2 col5" >38.902980</td>
#       <td id="T_97be0_row2_col6" class="data row2 col6" >5.097304</td>
#       <td id="T_97be0_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_97be0_row2_col8" class="data row2 col8" >18.316740</td>
#       <td id="T_97be0_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_97be0_row2_col10" class="data row2 col10" >360.238316</td>
#       <td id="T_97be0_row2_col11" class="data row2 col11" >25.314320</td>
#       <td id="T_97be0_row2_col12" class="data row2 col12" >0.348087</td>
#       <td id="T_97be0_row2_col13" class="data row2 col13" >0.000003</td>
#       <td id="T_97be0_row2_col14" class="data row2 col14" >0.144986</td>
#       <td id="T_97be0_row2_col15" class="data row2 col15" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_97be0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_97be0_row3_col0" class="data row3 col0" >Airline</td>
#       <td id="T_97be0_row3_col1" class="data row3 col1" >LLA</td>
#       <td id="T_97be0_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_97be0_row3_col3" class="data row3 col3" >last_layer</td>
#       <td id="T_97be0_row3_col4" class="data row3 col4" >diag</td>
#       <td id="T_97be0_row3_col5" class="data row3 col5" >38.902980</td>
#       <td id="T_97be0_row3_col6" class="data row3 col6" >5.097321</td>
#       <td id="T_97be0_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_97be

# %%
pd.set_option("display.precision", 3)
regression.query("dataset == 'Airline'")[subset].reset_index()
# Out:
#    dataset  model       M      subset hessian    RMSE    NLL    CRPS      Q
#                                                  mean   mean    mean   mean
# 0  Airline   ELLA  2000.0         NaN     NaN  38.903  5.086  18.437  0.158
# 1  Airline    LLA     NaN         all    diag  38.903  5.097  18.319  0.145
# 2  Airline    LLA     NaN         all    kron  38.903  5.097  18.317  0.145
# 3  Airline    LLA     NaN  last_layer    diag  38.903  5.097  18.317  0.145
# 4  Airline    LLA     NaN  last_layer    full  38.903  5.097  18.317  0.145
# 5  Airline    LLA     NaN  last_layer    kron  38.903  5.097  18.317  0.145
# 6  Airline    MAP     NaN         NaN     NaN  38.903  5.087  18.436  0.158
# 7  Airline  VaLLA   100.0         NaN     NaN  38.903  4.923  18.610  0.109
# 8  Airline  VaLLA   200.0         NaN     NaN  38.903  4.918  18.615  0.107

# %%
def get_Q_plot_queries(dataset):
    return [
        #"dataset == '"+dataset+"' and model == 'MAP'",
        "dataset == '"+dataset+"' and model == 'ELLA'",
        "dataset == '"+dataset+"' and model == 'VaLLA' and M == 100",
        #"dataset == '"+dataset+"' and model == 'VaLLA' and M == 200",
        "dataset == '"+dataset+"' and model == 'LLA' and hessian == 'kron' and subset == 'all'",
        #"dataset == '"+dataset+"' and model == 'LLA' and hessian == 'diag' and subset == 'all'",
        #"dataset == '"+dataset+"' and model == 'LLA' and hessian == 'full' and subset == 'last_layer'"
    ]

Q_plot_labels = ["ELLA", "VaLLA", "LLA KFAC", "LLA Diag", r"LLA$^\star$"]
Q_plot_markes = [">", "<", "^", "v", "*", "o"]
Q_plot_linestyles = ["-", ":", "-", "-.", "--", ":", "--"]
columns = [('Q-10', 'mean'),
 ('Q-20', 'mean'),
 ('Q-30', 'mean'),
 ('Q-40', 'mean'),
 ('Q-50', 'mean'),
 ('Q-60', 'mean'),
 ('Q-70', 'mean'),
 ('Q-80', 'mean'),
 ('Q-90', 'mean')]

# %%
import matplotlib as mpl
import matplotlib
mpl.rcParams.update(mpl.rcParamsDefault)

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
plt.rcParams['figure.figsize'] = (16, 9)
fontsize = 32
matplotlib.rcParams.update({'font.size': fontsize})
jet = plt.colormaps["Dark2"]
plt.rcParams.update({
    'text.usetex': True,
    'text.latex.preamble': r'\usepackage{amsfonts}'
})
def Q_plot(dataset, axis):
    axis.xaxis.set_tick_params(labelsize=24)
    axis.yaxis.set_tick_params(labelsize=24)
    Q_queries_plot = get_Q_plot_queries(dataset)
    x = np.linspace(0, 1, 11)
    for i in range(len(Q_queries_plot)):
        axis.plot(x, [0, *regression.query(Q_queries_plot[i]).reset_index()[columns].to_numpy().flatten(), 1],
            label = Q_plot_labels[i], color = jet(i), lw = 4)

    axis.plot(x, x, color = "black",  lw = 3)
    axis.set_xlabel(r"$\alpha$")
    axis.set_ylabel(r"$\mathbb{P}_{(\mathbf{x}, y)}[y \in I(\mathbf{x}, \alpha)]$")

# %% [markdown]
# ### Year

# %%
regression.query("dataset == 'Year'").drop(Q_columns, axis = 1).reset_index().style.background_gradient(axis=0, subset = subset)
# Out:
# <style type="text/css">
# #T_5de54_row0_col5, #T_5de54_row1_col5, #T_5de54_row2_col5, #T_5de54_row2_col8, #T_5de54_row3_col5, #T_5de54_row3_col8, #T_5de54_row4_col5, #T_5de54_row4_col8, #T_5de54_row5_col5, #T_5de54_row5_col8, #T_5de54_row6_col5, #T_5de54_row7_col5, #T_5de54_row8_col5, #T_5de54_row8_col6, #T_5de54_row8_col14 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_5de54_row0_col6, #T_5de54_row0_col14, #T_5de54_row6_col6, #T_5de54_row6_col14, #T_5de54_row7_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5de54_row0_col8, #T_5de54_row1_col6, #T_5de54_row6_col8 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_5de54_row1_col8 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_5de54_row1_col14 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_5de54_row2_col6, #T_5de54_row3_col6, #T_5de54_row4_col6, #T_5de54_row5_col6 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_5de54_row2_col14 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_5de54_row3_col14, #T_5de54_row4_col14, #T_5de54_row5_col14 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_5de54_row7_col6 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_5de54_row7_col14 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_5de54_row8_col8 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5de54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5de54_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_5de54_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_5de54_level0_col2" class="col_heading level0 col2" >M</th>
#       <th id="T_5de54_level0_col3" class="col_heading level0 col3" >subset</th>
#       <th id="T_5de54_level0_col4" class="col_heading level0 col4" >hessian</th>
#       <th id="T_5de54_level0_col5" class="col_heading level0 col5" >RMSE</th>
#       <th id="T_5de54_level0_col6" class="col_heading level0 col6" colspan="2">NLL</th>
#       <th id="T_5de54_level0_col8" class="col_heading level0 col8" colspan="2">CRPS</th>
#       <th id="T_5de54_level0_col10" class="col_heading level0 col10" colspan="2">time</th>
#       <th id="T_5de54_level0_col12" class="col_heading level0 col12" colspan="2">prior_std</th>
#       <th id="T_5de54_level0_col14" class="col_heading level0 col14" colspan="2">Q</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_5de54_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_5de54_level1_col1" class="col_heading level1 col1" ></th>
#       <th id="T_5de54_level1_col2" class="col_heading level1 col2" ></th>
#       <th id="T_5de54_level1_col3" class="col_heading level1 col3" ></th>
#       <th id="T_5de54_level1_col4" class="col_heading level1 col4" ></th>
#       <th id="T_5de54_level1_col5" class="col_heading level1 col5" >mean</th>
#       <th id="T_5de54_level1_col6" class="col_heading level1 col6" >mean</th>
#       <th id="T_5de54_level1_col7" class="col_heading level1 col7" >std</th>
#       <th id="T_5de54_level1_col8" class="col_heading level1 col8" >mean</th>
#       <th id="T_5de54_level1_col9" class="col_heading level1 col9" >std</th>
#       <th id="T_5de54_level1_col10" class="col_heading level1 col10" >mean</th>
#       <th id="T_5de54_level1_col11" class="col_heading level1 col11" >std</th>
#       <th id="T_5de54_level1_col12" class="col_heading level1 col12" >mean</th>
#       <th id="T_5de54_level1_col13" class="col_heading level1 col13" >std</th>
#       <th id="T_5de54_level1_col14" class="col_heading level1 col14" >mean</th>
#       <th id="T_5de54_level1_col15" class="col_heading level1 col15" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5de54_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5de54_row0_col0" class="data row0 col0" >Year</td>
#       <td id="T_5de54_row0_col1" class="data row0 col1" >ELLA</td>
#       <td id="T_5de54_row0_col2" class="data row0 col2" >2000.000000</td>
#       <td id="T_5de54_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_5de54_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_5de54_row0_col5" class="data row0 col5" >9.316824</td>
#       <td id="T_5de54_row0_col6" class="data row0 col6" >3.674486</td>
#       <td id="T_5de54_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_5de54_row0_col8" class="data row0 col8" >5.055905</td>
#       <td id="T_5de54_row0_col9" class="data row0 col9" >0.000000</td>
#       <td id="T_5de54_row0_col10" class="data row0 col10" >168.309662</td>
#       <td id="T_5de54_row0_col11" class="data row0 col11" >12.557577</td>
#       <td id="T_5de54_row0_col12" class="data row0 col12" >0.001000</td>
#       <td id="T_5de54_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_5de54_row0_col14" class="data row0 col14" >0.163736</td>
#       <td id="T_5de54_row0_col15" class="data row0 col15" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5de54_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5de54_row1_col0" class="data row1 col0" >Year</td>
#       <td id="T_5de54_row1_col1" class="data row1 col1" >LLA</td>
#       <td id="T_5de54_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_5de54_row1_col3" class="data row1 col3" >all</td>
#       <td id="T_5de54_row1_col4" class="data row1 col4" >diag</td>
#       <td id="T_5de54_row1_col5" class="data row1 col5" >9.316824</td>
#       <td id="T_5de54_row1_col6" class="data row1 col6" >3.649988</td>
#       <td id="T_5de54_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_5de54_row1_col8" class="data row1 col8" >4.957107</td>
#       <td id="T_5de54_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_5de54_row1_col10" class="data row1 col10" >553.698587</td>
#       <td id="T_5de54_row1_col11" class="data row1 col11" >8.697368</td>
#       <td id="T_5de54_row1_col12" class="data row1 col12" >0.078496</td>
#       <td id="T_5de54_row1_col13" class="data row1 col13" >0.000000</td>
#       <td id="T_5de54_row1_col14" class="data row1 col14" >0.122091</td>
#       <td id="T_5de54_row1_col15" class="data row1 col15" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5de54_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5de54_row2_col0" class="data row2 col0" >Year</td>
#       <td id="T_5de54_row2_col1" class="data row2 col1" >LLA</td>
#       <td id="T_5de54_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_5de54_row2_col3" class="data row2 col3" >all</td>
#       <td id="T_5de54_row2_col4" class="data row2 col4" >kron</td>
#       <td id="T_5de54_row2_col5" class="data row2 col5" >9.316824</td>
#       <td id="T_5de54_row2_col6" class="data row2 col6" >3.650447</td>
#       <td id="T_5de54_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_5de54_row2_col8" class="data row2 col8" >4.954732</td>
#       <td id="T_5de54_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_5de54_row2_col10" class="data row2 col10" >676.943635</td>
#       <td id="T_5de54_row2_col11" class="data row2 col11" >2.482001</td>
#       <td id="T_5de54_row2_col12" class="data row2 col12" >0.165934</td>
#       <td id="T_5de54_row2_col13" class="data row2 col13" >0.000000</td>
#       <td id="T_5de54_row2_col14" class="data row2 col14" >0.120533</td>
#       <td id="T_5de54_row2_col15" class="data row2 col15" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5de54_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5de54_row3_col0" class="data row3 col0" >Year</td>
#       <td id="T_5de54_row3_col1" class="data row3 col1" >LLA</td>
#       <td id="T_5de54_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_5de54_row3_col3" class="data row3 col3" >last_layer</td>
#       <td id="T_5de54_row3_col4" class="data row3 col4" >diag</td>
#       <td id="T_5de54_row3_col5" class="data row3 col5" >9.316824</td>
#       <td id="T_5de54_row3_col6" class="data row3 col6" >3.650757</td>
#       <td id="T_5de54_row3_col7" class="data row3 col7" >0.000000</td>
#       <td id="T_5de54_row3_col8" class="d

# %%
regression.query("dataset == 'Year'")[subset].reset_index()
# Out:
#   dataset  model       M      subset hessian   RMSE    NLL   CRPS      Q
#                                                mean   mean   mean   mean
# 0    Year   ELLA  2000.0         NaN     NaN  9.317  3.674  5.056  0.164
# 1    Year    LLA     NaN         all    diag  9.317  3.650  4.957  0.122
# 2    Year    LLA     NaN         all    kron  9.317  3.650  4.955  0.121
# 3    Year    LLA     NaN  last_layer    diag  9.317  3.651  4.954  0.120
# 4    Year    LLA     NaN  last_layer    full  9.317  3.651  4.954  0.120
# 5    Year    LLA     NaN  last_layer    kron  9.317  3.651  4.954  0.120
# 6    Year    MAP     NaN         NaN     NaN  9.317  3.674  5.056  0.164
# 7    Year  VaLLA   100.0         NaN     NaN  9.317  3.527  5.071  0.084
# 8    Year  VaLLA   200.0         NaN     NaN  9.317  3.493  5.026  0.076

# %% [markdown]
# ### Taxi

# %%
regression.query("dataset == 'Taxi'").drop(Q_columns, axis = 1).reset_index().style.background_gradient(axis=0, subset = subset)
# Out:
# <style type="text/css">
# #T_a9b6f_row0_col5, #T_a9b6f_row0_col8, #T_a9b6f_row1_col5, #T_a9b6f_row2_col5, #T_a9b6f_row3_col5, #T_a9b6f_row4_col5, #T_a9b6f_row5_col5, #T_a9b6f_row6_col5, #T_a9b6f_row6_col8, #T_a9b6f_row7_col5, #T_a9b6f_row7_col14, #T_a9b6f_row8_col5, #T_a9b6f_row8_col6, #T_a9b6f_row8_col14 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a9b6f_row0_col6 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_a9b6f_row0_col14 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_a9b6f_row1_col6, #T_a9b6f_row7_col8 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_a9b6f_row1_col8 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_a9b6f_row1_col14, #T_a9b6f_row2_col14, #T_a9b6f_row6_col6, #T_a9b6f_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a9b6f_row2_col6 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_a9b6f_row2_col8 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_a9b6f_row3_col6, #T_a9b6f_row4_col6, #T_a9b6f_row5_col6 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_a9b6f_row3_col8, #T_a9b6f_row4_col8, #T_a9b6f_row5_col8 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_a9b6f_row3_col14, #T_a9b6f_row4_col14, #T_a9b6f_row5_col14 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_a9b6f_row6_col14 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_a9b6f_row7_col6 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# </style>
# <table id="T_a9b6f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9b6f_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_a9b6f_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_a9b6f_level0_col2" class="col_heading level0 col2" >M</th>
#       <th id="T_a9b6f_level0_col3" class="col_heading level0 col3" >subset</th>
#       <th id="T_a9b6f_level0_col4" class="col_heading level0 col4" >hessian</th>
#       <th id="T_a9b6f_level0_col5" class="col_heading level0 col5" >RMSE</th>
#       <th id="T_a9b6f_level0_col6" class="col_heading level0 col6" colspan="2">NLL</th>
#       <th id="T_a9b6f_level0_col8" class="col_heading level0 col8" colspan="2">CRPS</th>
#       <th id="T_a9b6f_level0_col10" class="col_heading level0 col10" colspan="2">time</th>
#       <th id="T_a9b6f_level0_col12" class="col_heading level0 col12" colspan="2">prior_std</th>
#       <th id="T_a9b6f_level0_col14" class="col_heading level0 col14" colspan="2">Q</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a9b6f_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_a9b6f_level1_col1" class="col_heading level1 col1" ></th>
#       <th id="T_a9b6f_level1_col2" class="col_heading level1 col2" ></th>
#       <th id="T_a9b6f_level1_col3" class="col_heading level1 col3" ></th>
#       <th id="T_a9b6f_level1_col4" class="col_heading level1 col4" ></th>
#       <th id="T_a9b6f_level1_col5" class="col_heading level1 col5" >mean</th>
#       <th id="T_a9b6f_level1_col6" class="col_heading level1 col6" >mean</th>
#       <th id="T_a9b6f_level1_col7" class="col_heading level1 col7" >std</th>
#       <th id="T_a9b6f_level1_col8" class="col_heading level1 col8" >mean</th>
#       <th id="T_a9b6f_level1_col9" class="col_heading level1 col9" >std</th>
#       <th id="T_a9b6f_level1_col10" class="col_heading level1 col10" >mean</th>
#       <th id="T_a9b6f_level1_col11" class="col_heading level1 col11" >std</th>
#       <th id="T_a9b6f_level1_col12" class="col_heading level1 col12" >mean</th>
#       <th id="T_a9b6f_level1_col13" class="col_heading level1 col13" >std</th>
#       <th id="T_a9b6f_level1_col14" class="col_heading level1 col14" >mean</th>
#       <th id="T_a9b6f_level1_col15" class="col_heading level1 col15" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9b6f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9b6f_row0_col0" class="data row0 col0" >Taxi</td>
#       <td id="T_a9b6f_row0_col1" class="data row0 col1" >ELLA</td>
#       <td id="T_a9b6f_row0_col2" class="data row0 col2" >2000.000000</td>
#       <td id="T_a9b6f_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_a9b6f_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_a9b6f_row0_col5" class="data row0 col5" >9.968822</td>
#       <td id="T_a9b6f_row0_col6" class="data row0 col6" >3.752528</td>
#       <td id="T_a9b6f_row0_col7" class="data row0 col7" >0.000502</td>
#       <td id="T_a9b6f_row0_col8" class="data row0 col8" >3.753702</td>
#       <td id="T_a9b6f_row0_col9" class="data row0 col9" >0.000017</td>
#       <td id="T_a9b6f_row0_col10" class="data row0 col10" >1027.302347</td>
#       <td id="T_a9b6f_row0_col11" class="data row0 col11" >121.901142</td>
#       <td id="T_a9b6f_row0_col12" class="data row0 col12" >0.900000</td>
#       <td id="T_a9b6f_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_a9b6f_row0_col14" class="data row0 col14" >0.227051</td>
#       <td id="T_a9b6f_row0_col15" class="data row0 col15" >0.000004</td>
#     </tr>
#     <tr>
#       <th id="T_a9b6f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9b6f_row1_col0" class="data row1 col0" >Taxi</td>
#       <td id="T_a9b6f_row1_col1" class="data row1 col1" >LLA</td>
#       <td id="T_a9b6f_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_a9b6f_row1_col3" class="data row1 col3" >all</td>
#       <td id="T_a9b6f_row1_col4" class="data row1 col4" >diag</td>
#       <td id="T_a9b6f_row1_col5" class="data row1 col5" >9.968822</td>
#       <td id="T_a9b6f_row1_col6" class="data row1 col6" >3.714031</td>
#       <td id="T_a9b6f_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_a9b6f_row1_col8" class="data row1 col8" >3.978643</td>
#       <td id="T_a9b6f_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_a9b6f_row1_col10" class="data row1 col10" >403.369916</td>
#       <td id="T_a9b6f_row1_col11" class="data row1 col11" >4.988066</td>
#       <td id="T_a9b6f_row1_col12" class="data row1 col12" >0.068213</td>
#       <td id="T_a9b6f_row1_col13" class="data row1 col13" >0.000000</td>
#       <td id="T_a9b6f_row1_col14" class="data row1 col14" >0.270126</td>
#       <td id="T_a9b6f_row1_col15" class="data row1 col15" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a9b6f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9b6f_row2_col0" class="data row2 col0" >Taxi</td>
#       <td id="T_a9b6f_row2_col1" class="data row2 col1" >LLA</td>
#       <td id="T_a9b6f_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_a9b6f_row2_col3" class="data row2 col3" >all</td>
#       <td id="T_a9b6f_row2_col4" class="data row2 col4" >kron</td>
#       <td id="T_a9b6f_row2_col5" class="data row2 col5" >9.968822</td>
#       <td id="T_a9b6f_row2_col6" class="data row2 col6" >3.704988</td>
#       <td id="T_a9b6f_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_a9b6f_row2_col8" class="data row2 col8" >3.977261</td>
#       <td id="T_a9b6f_row2_col9" class="data row2 col9" >0.000000</td>
#       <td id="T_a9b6f_row2_col10" class="data row2 col10" >557.200931</td>
#       <td id="T_a9b6f_row2_col11" class="data row2 col11" >6.972215</td>
#       <td id="T_a9b6f_row2_col12" class="data row2 col12" >0.354008</td>
#       <td id="T_a9b6f_row2_col13" class="data row2 col13" >0.000000</td>
#       <td id="T_a9b6f_row2_col14" class="data row2 col14" >0.269828</td>
#       <td id="T_a9b6f_row2_col15" class="data row2 col15" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a9b6f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a9b6f_row3_col0" class="data row3 col0" >Taxi</td>
#       <td id="T_a9b6f_row3_col1" class="data row3 col1" >LLA</td>
#       <td id="T_a9b6f_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_a9b6f_row3_col3" class="data row3 col3" >last_layer</td>
#       <td id="T_a9b6f_row3_col4" class="data row3 col4" >diag</td>
#       <td id="T_a9b6f_row3_col5" class="data row3 col5" >9.968822</td>
#       <td id="T_a9b6f_row3_col6" class="data row3 col6" >3.718337</td>
#       <td

# %%
regression.query("dataset == 'Taxi'")[subset].reset_index()
# Out:
#   dataset  model       M      subset hessian   RMSE    NLL   CRPS      Q
#                                                mean   mean   mean   mean
# 0    Taxi   ELLA  2000.0         NaN     NaN  9.969  3.753  3.754  0.227
# 1    Taxi    LLA     NaN         all    diag  9.969  3.714  3.979  0.270
# 2    Taxi    LLA     NaN         all    kron  9.969  3.705  3.977  0.270
# 3    Taxi    LLA     NaN  last_layer    diag  9.969  3.718  3.976  0.270
# 4    Taxi    LLA     NaN  last_layer    full  9.969  3.718  3.976  0.270
# 5    Taxi    LLA     NaN  last_layer    kron  9.969  3.718  3.976  0.270
# 6    Taxi    MAP     NaN         NaN     NaN  9.969  3.763  3.753  0.227
# 7    Taxi  VaLLA   100.0         NaN     NaN  9.969  3.287  3.968  0.188
# 8    Taxi  VaLLA   200.0         NaN     NaN  9.969  3.280  3.993  0.188

# %%
fig, axis = plt.subplots(1, 1, figsize=(9, 7))
Q_plot("Year", axis)
plt.legend(fontsize = 24)
fig.tight_layout()
plt.savefig("Q_Year_plot.pdf", format = "pdf", bbox_inches='tight')
plt.show()

# %%
fig, axis = plt.subplots(1, 1, figsize=(9, 7))
Q_plot("Airline", axis)
plt.legend(fontsize = 24)
fig.tight_layout()
plt.savefig("Q_Airline_plot.pdf", format = "pdf", bbox_inches='tight')
plt.show()

# %%
fig, axis = plt.subplots(1, 1, figsize=(9, 7))
Q_plot("Taxi", axis)
plt.legend(fontsize = 24)
fig.tight_layout()
plt.savefig("Q_Taxi_plot.pdf", format = "pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# # Classification Fully-Connected 200-200

# %% [markdown]
# ### Trainable/Validated Prior

# %%
def plot_corruptions(dataset, metric, c_values, axis):
    set = plt.colormaps["Dark2"]
    q = multiclass.query("dataset == '{}'".format(dataset))[[(metric + "-C"+str(i), "mean") for i in c_values]]
    q_stds = multiclass.query("dataset == '{}'".format(dataset))[[(metric + "-C"+str(i), "std") for i in c_values]]

    axis.plot(c_values, q.query("model == 'MAP'").to_numpy()[0], label = "MAP", lw = 4, color = set(0))
    lw = 5
    #cur_q = "model == 'LLA' and hessian == 'diag' and subset == 'all'"
    # axis.plot(c_values, q.query(cur_q).to_numpy()[0], 
    #          label = "LLA Diag", lw = 4)
    # axis.plot(c_values, q.query("model == 'LLA' and hessian == 'kron' and subset == 'all'").to_numpy()[0], 
    #          label = "LLA KFAC", lw = 4)
    axis.plot(c_values, q.query("model == 'LLA' and hessian == 'kron' and subset == 'last_layer'").to_numpy()[0],
               label = "LLA* KFAC", lw = lw, color = set(1))
    axis.plot(c_values, q.query("model == 'LLA' and hessian == 'full' and subset == 'last_layer'").to_numpy()[0],
               label = "LLA*", lw = lw, color = set(2))
    axis.plot(c_values, q.query("model == 'ELLA'").to_numpy()[0], label = "ELLA", lw = lw, color = set(3))
    axis.plot(c_values, q.query("model == 'VaLLA' and M == 100").to_numpy()[0],
               label = "VaLLA 100", lw = lw, color = set(4))
    axis.plot(c_values, q.query("model == 'VaLLA' and M == 200").to_numpy()[0], 
              label = "VaLLA 200", lw = lw, color = set(5))
    axis.set_xticks(np.linspace(10, 180, 3))
    axis.xaxis.set_tick_params(labelsize=18)
    axis.yaxis.set_tick_params(labelsize=18)
    axis.set_xlabel("Rotation degrees")
    axis.set_ylabel(metric)
    #axis.legend()

# %%
subset =  [("ACC", "mean"), ("NLL", "mean"), ("ECE", "mean"),("BRIER", "mean"),  ("OOD-AUC", "mean"), 
           ("ACC MC", "mean"),
            ("NLL MC", "mean"),
            ("ECE MC", "mean"),
            ("BRIER MC", "mean"),  
            ("OOD-AUC MC", "mean"),
            ("prior_std", "mean"),
            ("time", "mean")]

# %% [markdown]
# #### FMNIST

# %%
fig, axis = plt.subplots(1, 3, figsize=(25, 4))
plot_corruptions("FMNIST", "ACC", range(10, 190, 10), axis[0])
plot_corruptions("FMNIST", "ECE", range(10, 190, 10), axis[1])
plot_corruptions("FMNIST", "NLL", range(10, 190, 10), axis[2])

plt.legend(loc='lower center', bbox_to_anchor=(-0.7, -0.6),
          ncol = 6, fancybox=True, shadow=True)
fig.tight_layout()
plt.savefig("Rotations_FMNIST.pdf", format = "pdf", bbox_inches='tight')

plt.show()
# Out:
# /tmp/ipykernel_114841/274604456.py:8: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.tight_layout()

# %%
multiclass.query("dataset == 'FMNIST'")[subset].reset_index().style.background_gradient(axis=0, subset = subset)
# Out:
# <style type="text/css">
# #T_e858c_row0_col6 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_e858c_row0_col7 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_e858c_row0_col8, #T_e858c_row4_col13, #T_e858c_row7_col17 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_e858c_row0_col9, #T_e858c_row3_col11, #T_e858c_row7_col10 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_e858c_row0_col10, #T_e858c_row0_col15, #T_e858c_row1_col6, #T_e858c_row3_col8, #T_e858c_row3_col12, #T_e858c_row3_col13, #T_e858c_row3_col14, #T_e858c_row3_col17, #T_e858c_row5_col17, #T_e858c_row6_col10, #T_e858c_row6_col15, #T_e858c_row6_col17, #T_e858c_row7_col11, #T_e858c_row7_col16, #T_e858c_row9_col7, #T_e858c_row9_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e858c_row0_col11 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_e858c_row0_col12, #T_e858c_row0_col13, #T_e858c_row0_col14, #T_e858c_row0_col17, #T_e858c_row8_col11 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_e858c_row0_col16, #T_e858c_row1_col7, #T_e858c_row1_col8, #T_e858c_row1_col9, #T_e858c_row1_col12, #T_e858c_row1_col13, #T_e858c_row1_col14, #T_e858c_row4_col17, #T_e858c_row5_col11, #T_e858c_row9_col6, #T_e858c_row9_col10, #T_e858c_row9_col15 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e858c_row1_col10 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_e858c_row1_col11, #T_e858c_row2_col9 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_e858c_row1_col15 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_e858c_row1_col16 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_e858c_row1_col17, #T_e858c_row2_col17, #T_e858c_row5_col13 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_e858c_row2_col6, #T_e858c_row7_col8 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_e858c_row2_col7 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_e858c_row2_col8 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_e858c_row2_col10, #T_e858c_row7_col6 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_e858c_row2_col11, #T_e858c_row4_col11 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_e858c_row2_col12 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_e858c_row2_col13 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_e858c_row2_col14 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_e858c_row2_col15 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_e858c_row2_col16 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_e858c_row3_col6 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_e858c_row3_col7 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_e858c_row3_col9 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_e858c_row3_col10, #T_e858c_row8_col7 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_e858c_row3_col15, #T_e858c_row5_col15 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_e858c_row3_col16, #T_e858c_row4_col12, #T_e858c_row4_col14 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_e858c_row4_col6 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_e858c_row4_col7 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_e858c_row4_col8, #T_e858c_row4_col15, #T_e858c_row5_col14 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_e858c_row4_col9, #T_e858c_row5_col9 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_e858c_row4_col10 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_e858c_row4_col16 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_e858c_row5_col6 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_e858c_row5_col7 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_e858c_row5_col8 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_e858c_row5_col10 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_e858c_row5_col12 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_e858c_row5_col16 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_e858c_row6_col6 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_e858c_row6_col7 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_e858c_row6_col8, #T_e858c_row8_col17, #T_e858c_row9_col16 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_e858c_row6_col9, #T_e858c_row9_col13 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_e858c_row6_col11 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_e858c_row6_col12, #T_e858c_row6_col13, #T_e858c_row6_col14 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_e858c_row6_col16 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_e858c_row7_col7 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_e858c_row7_col9 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_e858c_row7_col12 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_e858c_row7_col13 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_e858c_row7_col14 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_e858c_row7_col15 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_e858c_row8_col6 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_e858c_row8_col8, #T_e858c_row9_col8 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_e858c_row8_col9 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_e858c_row8_col10 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_e858c_row8_col12 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_e858c_row8_col13 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_e858c_row8_col14 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_e858c_row8_col15 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_e858c_row8_col16 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_e858c_row9_col11 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_e858c_row9_col12 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_e858c_row9_col14 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_e858c_row9_col17 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# </style>
# <table id="T_e858c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e858c_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_e858c_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_e858c_level0_col2" class="col_heading level0 col2" >M</th>
#       <th id="T_e858c_level0_col3" class="col_heading level0 col3" >subset</th>
#       <th id="T_e858c_level0_col4" class="col_heading level0 col4" >hessian</th>
#       <th id="T_e858c_level0_col5" class="col_heading level0 col5" >alpha</th>
#       <th id="T_e858c_level0_col6" class="col_heading level0 col6" >ACC</th>
#       <th id="T_e858c_level0_col7" class="col_heading level0 col7" >NLL</th>
#       <th id="T_e858c_level0_col8" class="col_heading level0 col8" >ECE</th>
#       <th id="T_e858c_level0_col9" class="col_heading level0 col9" >BRIER</th>
#       <th id="T_e858c_level0_col10" class="col_heading level0 col10" >OOD-AUC</th>
#       <th id="T_e858c_level0_col11" class="col_heading level0 col11" >ACC MC</th>
#       <th id="T_e858c_level0_col12" class="col_heading level0 col12" >NLL MC</th>
#       <th id="T_e858c_level0_col13" class="col_heading level0 col13" >ECE MC</th>
#       <th id="T_e858c_level0_col14" class="col_heading level0 col14" >BRIER MC</th>
#       <th id="T_e858c_level0_col15" class="col_heading level0 col15" >OOD-AUC MC</th>
#       <th id="T_e858c_level0_col16" class="col_heading level0 col16" >prior_std</th>
#       <th id="T_e858c_level0_col17" class="col_heading level0 col17" >time</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_e858c_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_e858c_level1_col1" class="col_heading level1 col1" ></th>
#       <th id="T_e858c_level1_col2" class="col_heading level1 col2" ></th>
#       <th id="T_e858c_level1_col3" class="col_heading level1 col3" ></th>
#       <th id="T_e858c_level1_col4" class="col_heading level1 col4" ></th>
#       <th id="T_e858c_level1_col5" class="col_heading level1 col5" ></th>
#       <th id="T_e858c_level1_col6" class="col_heading level1 col6" >mean</th>
#       <th id="T_e85

# %%
multiclass.query("dataset == 'FMNIST'")[subset].reset_index()
# Out:
#   dataset  model       M      subset hessian alpha    ACC    NLL    ECE  \
#                                                      mean   mean   mean
# 0  FMNIST   ELLA  2000.0         NaN     NaN   NaN  0.866  0.373  0.008
# 1  FMNIST    LLA     NaN         all    diag   NaN  0.862  0.397  0.043
# 2  FMNIST    LLA     NaN         all    kron   NaN  0.865  0.377  0.014
# 3  FMNIST    LLA     NaN  last_layer    diag   NaN  0.865  0.374  0.006
# 4  FMNIST    LLA     NaN  last_layer    full   NaN  0.866  0.373  0.008
# 5  FMNIST    LLA     NaN  last_layer    kron   NaN  0.866  0.373  0.008
# 6  FMNIST    MAP     NaN         NaN     NaN   NaN  0.866  0.373  0.009
# 7  FMNIST  VaLLA   100.0         NaN     NaN   1.0  0.874  0.355  0.011
# 8  FMNIST  VaLLA   200.0         NaN     NaN   1.0  0.876  0.352  0.013
# 9  FMNIST  VaLLA   500.0         NaN     NaN   1.0  0.877  0.349  0.013
#
#    BRIER OOD-AUC ACC MC NLL MC ECE MC BRIER MC OOD-AUC MC prior_std       time
#     mean    mean   mean   mean   mean     mean       mean      mean       mean
# 0  0.193   0.874  0.866  0.373  0.008    0.193      0.874     0.840   1337.935
# 1  0.201   0.914  0.866  0.398  0.062    0.201      0.908     0.092    315.173
# 2  0.194   0.932  0.867  0.373  0.017    0.193      0.933     0.183    250.853
# 3  0.194   0.879  0.866  0.372  0.007    0.193      0.878     0.146     42.627
# 4  0.193   0.882  0.867  0.375  0.009    0.194      0.879     0.307  46567.896
# 5  0.193   0.880  0.867  0.374  0.007    0.193      0.878     0.284     48.783
# 6  0.193   0.874  0.866  0.373  0.009    0.193      0.874       NaN      0.000
# 7  0.182   0.923  0.865  0.379  0.026    0.195      0.915     0.081   2244.138
# 8  0.181   0.933  0.865  0.382  0.032    0.196      0.926     0.101   3627.251
# 9  0.179   0.949  0.865  0.390  0.043    0.198      0.943     0.139   9130.125

# %% [markdown]
# #### MNIST

# %%
fig, axis = plt.subplots(1, 3, figsize=(25, 5))
plot_corruptions("MNIST", "ACC", range(10, 190, 10), axis[0])
plot_corruptions("MNIST", "ECE", range(10, 190, 10), axis[1])
plot_corruptions("MNIST", "NLL", range(10, 190, 10), axis[2])

plt.legend(loc='lower center', bbox_to_anchor=(-0.7, -0.35),
          ncol = 6, fancybox=True, shadow=True)
fig.tight_layout()
plt.savefig("Rotations_MNIST.pdf", format = "pdf", bbox_inches='tight')

plt.show()
# Out:
# /tmp/ipykernel_114841/292695060.py:8: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.tight_layout()

# %%
multiclass.query("dataset == 'MNIST'")[subset].reset_index().style.background_gradient(axis=0, subset = subset)
# Out:
# <style type="text/css">
# #T_204f8_row0_col6, #T_204f8_row4_col6, #T_204f8_row6_col6 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_204f8_row0_col7, #T_204f8_row0_col10, #T_204f8_row6_col7, #T_204f8_row6_col10, #T_204f8_row7_col7 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_204f8_row0_col8, #T_204f8_row0_col12, #T_204f8_row0_col13, #T_204f8_row0_col14, #T_204f8_row0_col16, #T_204f8_row1_col6, #T_204f8_row1_col11, #T_204f8_row3_col10, #T_204f8_row3_col17, #T_204f8_row4_col15, #T_204f8_row5_col17, #T_204f8_row6_col8, #T_204f8_row6_col12, #T_204f8_row6_col13, #T_204f8_row6_col14, #T_204f8_row6_col17, #T_204f8_row9_col7, #T_204f8_row9_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_204f8_row0_col9, #T_204f8_row6_col9, #T_204f8_row7_col16 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_204f8_row0_col11, #T_204f8_row2_col11, #T_204f8_row3_col11, #T_204f8_row6_col11, #T_204f8_row9_col11 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_204f8_row0_col15, #T_204f8_row3_col13, #T_204f8_row6_col15 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_204f8_row0_col17, #T_204f8_row5_col13, #T_204f8_row5_col15, #T_204f8_row7_col9, #T_204f8_row7_col13, #T_204f8_row8_col8 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_204f8_row1_col7, #T_204f8_row1_col8, #T_204f8_row1_col9, #T_204f8_row1_col12, #T_204f8_row1_col13, #T_204f8_row1_col14, #T_204f8_row2_col10, #T_204f8_row2_col15, #T_204f8_row4_col16, #T_204f8_row4_col17, #T_204f8_row7_col11, #T_204f8_row8_col11, #T_204f8_row9_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_204f8_row1_col10 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_204f8_row1_col15 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_204f8_row1_col16 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_204f8_row1_col17 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_204f8_row2_col6 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_204f8_row2_col7 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_204f8_row2_col8 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_204f8_row2_col9 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_204f8_row2_col12 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_204f8_row2_col13 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_204f8_row2_col14 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_204f8_row2_col16 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_204f8_row2_col17, #T_204f8_row7_col12, #T_204f8_row8_col14 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_204f8_row3_col6 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_204f8_row3_col7, #T_204f8_row3_col8 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_204f8_row3_col9 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_204f8_row3_col12, #T_204f8_row8_col12 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_204f8_row3_col14, #T_204f8_row5_col14, #T_204f8_row8_col9 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_204f8_row3_col15, #T_204f8_row4_col10, #T_204f8_row8_col17 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_204f8_row3_col16 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_204f8_row4_col7, #T_204f8_row7_col17 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_204f8_row4_col8 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_204f8_row4_col9, #T_204f8_row5_col9 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_204f8_row4_col11, #T_204f8_row5_col11 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_204f8_row4_col12, #T_204f8_row9_col14 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_204f8_row4_col13, #T_204f8_row9_col12 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_204f8_row4_col14 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_204f8_row5_col6 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_204f8_row5_col7 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_204f8_row5_col8, #T_204f8_row9_col13 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_204f8_row5_col10, #T_204f8_row8_col16 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_204f8_row5_col12, #T_204f8_row7_col8 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_204f8_row5_col16 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_204f8_row6_col16 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_204f8_row7_col6 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_204f8_row7_col10 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_204f8_row7_col14 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_204f8_row7_col15 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_204f8_row8_col6 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_204f8_row8_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_204f8_row8_col10 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_204f8_row8_col13 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_204f8_row8_col15 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_204f8_row9_col8 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_204f8_row9_col10 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_204f8_row9_col15 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_204f8_row9_col16 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_204f8_row9_col17 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# </style>
# <table id="T_204f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_204f8_level0_col0" class="col_heading level0 col0" >dataset</th>
#       <th id="T_204f8_level0_col1" class="col_heading level0 col1" >model</th>
#       <th id="T_204f8_level0_col2" class="col_heading level0 col2" >M</th>
#       <th id="T_204f8_level0_col3" class="col_heading level0 col3" >subset</th>
#       <th id="T_204f8_level0_col4" class="col_heading level0 col4" >hessian</th>
#       <th id="T_204f8_level0_col5" class="col_heading level0 col5" >alpha</th>
#       <th id="T_204f8_level0_col6" class="col_heading level0 col6" >ACC</th>
#       <th id="T_204f8_level0_col7" class="col_heading level0 col7" >NLL</th>
#       <th id="T_204f8_level0_col8" class="col_heading level0 col8" >ECE</th>
#       <th id="T_204f8_level0_col9" class="col_heading level0 col9" >BRIER</th>
#       <th id="T_204f8_level0_col10" class="col_heading level0 col10" >OOD-AUC</th>
#       <th id="T_204f8_level0_col11" class="col_heading level0 col11" >ACC MC</th>
#       <th id="T_204f8_level0_col12" class="col_heading level0 col12" >NLL MC</th>
#       <th id="T_204f8_level0_col13" class="col_heading level0 col13" >ECE MC</th>
#       <th id="T_204f8_level0_col14" class="col_heading level0 col14" >BRIER MC</th>
#       <th id="T_204f8_level0_col15" class="col_heading level0 col15" >OOD-AUC MC</th>
#       <th id="T_204f8_level0_col16" class="col_heading level0 col16" >prior_std</th>
#       <th id="T_204f8_level0_col17" class="col_heading level0 col17" >time</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_204f8_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_204f8_level1_col1" class="col_heading level1 col1" ></th>
#       <th id="T_204f8_level1_col2" class="col_heading level1 col2" ></th>
#       <th id="T_204f8_level1_col3" class="col_heading level1 col3" ></th>
#       <th id="T_204f8_level1_col4" class="col_heading level1 col4" ></th>
#       <th id="T_204f8_level1_col5" class="col_heading level1 col5" ></th>
#       <th id="T_204f8_level1_col6" class="col_heading level1 col6" >mean</th>
#       <th id="T_204f8_level1_col7" class="col_heading level1 col7" >mean</th>
#       <th id="T_204f8_level1_col8" class="col_heading level1 col8" >mean</th>
#       <th id="T_204f8_level1_col9" class="col_heading level1 col9" >mean</th>
#       <th id="T_204f8_level1_col10" class="col_heading level1 col10" >mean</th>
#       <th id="T_204f8_level1_col11" class="col_heading level1 col11" >mean</th>
#       <th id="T_204f8_level1_col12" class="col_heading level1 col12" >mean</th>
#       <th id="T_204f8_level1_col13" class="col_heading level1 col13" >mean</th>
#       <th id="T

# %%
multiclass.query("dataset == 'MNIST'")[subset].reset_index()
# Out:
#   dataset  model       M      subset hessian alpha    ACC    NLL    ECE  \
#                                                      mean   mean   mean
# 0   MNIST   ELLA  2000.0         NaN     NaN   NaN  0.976  0.076  0.008
# 1   MNIST    LLA     NaN         all    diag   NaN  0.974  0.143  0.072
# 2   MNIST    LLA     NaN         all    kron   NaN  0.975  0.094  0.029
# 3   MNIST    LLA     NaN  last_layer    diag   NaN  0.976  0.080  0.013
# 4   MNIST    LLA     NaN  last_layer    full   NaN  0.976  0.081  0.015
# 5   MNIST    LLA     NaN  last_layer    kron   NaN  0.976  0.081  0.015
# 6   MNIST    MAP     NaN         NaN     NaN   NaN  0.976  0.076  0.008
# 7   MNIST  VaLLA   100.0         NaN     NaN   1.0  0.977  0.076  0.010
# 8   MNIST  VaLLA   200.0         NaN     NaN   1.0  0.977  0.075  0.011
# 9   MNIST  VaLLA   500.0         NaN     NaN   1.0  0.977  0.075  0.012
#
#    BRIER OOD-AUC ACC MC NLL MC ECE MC BRIER MC OOD-AUC MC prior_std       time
#     mean    mean   mean   mean   mean     mean       mean      mean       mean
# 0  0.036   0.905  0.976  0.076  0.008    0.036      0.905     0.001   1654.155
# 1  0.053   0.922  0.976  0.159  0.093    0.057      0.936     0.109    326.551
# 2  0.041   0.949  0.976  0.098  0.036    0.041      0.959     0.186    985.222
# 3  0.037   0.904  0.976  0.079  0.013    0.037      0.908     0.190     47.798
# 4  0.037   0.909  0.976  0.080  0.014    0.037      0.901     0.384  33590.535
# 5  0.037   0.909  0.976  0.079  0.012    0.037      0.904     0.365     51.632
# 6  0.036   0.905  0.976  0.076  0.008    0.036      0.905       NaN      0.000
# 7  0.036   0.916  0.976  0.078  0.012    0.037      0.914     0.033   3170.863
# 8  0.035   0.921  0.976  0.079  0.014    0.037      0.917     0.041   4041.698
# 9  0.035   0.929  0.976  0.082  0.017    0.038      0.925     0.056  10804.546

# %% [markdown]
# # Resnet

# %%
resnet20 = [i for i in glob.glob("results/VaLLA_resnet20*")]
df = []
for f in resnet20:
    try:
        df.append(pd.read_csv(f))
    except:
        continue
resnet20 =pd.concat(df)
resnet32 = [i for i in glob.glob("results/VaLLA_resnet32*")]
df = []
for f in resnet32:
    try:
        df.append(pd.read_csv(f))
    except:
        continue
resnet32 =pd.concat(df)
resnet44 = [i for i in glob.glob("results/VaLLA_resnet44*")]
df = []
for f in resnet44:
    try:
        df.append(pd.read_csv(f))
    except:
        continue
resnet44 =pd.concat(df)
resnet56 = [i for i in glob.glob("results/VaLLA_resnet56*")]
df = []
for f in resnet56:
    try:
        df.append(pd.read_csv(f))
    except:
        continue
resnet56 =pd.concat(df)

# %%
resnet20["model"] = "Resnet20"
resnet32["model"] = "Resnet32"
resnet44["model"] = "Resnet44"
resnet56["model"] = "Resnet56"

# %%
resnet20.columns
# Out:
# Index(['Unnamed: 0', 'LOSS', 'NLL', 'ACC', 'ECE', 'BRIER', 'NLL MC', 'ACC MC',
#        'ECE MC', 'BRIER MC',
#        ...
#        'LOSS-C-18-4', 'NLL-C-18-4', 'ACC-C-18-4', 'ECE-C-18-4', 'BRIER-C-18-4',
#        'NLL MC-C-18-4', 'ACC MC-C-18-4', 'ECE MC-C-18-4', 'BRIER MC-C-18-4',
#        'model'],
#       dtype='object', length=877)

# %%
df = pd.concat([resnet20, resnet32, resnet44, resnet56]).drop(
    ["LOSS", "Unnamed: 0", "iterations", "weight_decay", "MAP_iterations", "timer"], axis=1
).query("M == 100")

# %%
df[["model", "M", "ACC", "NLL", "ECE", "BRIER",  "ACC MC", "NLL MC", "ECE MC", "BRIER MC"]].groupby(["model", "M"]).mean()
# Out:
#                 ACC    NLL    ECE  BRIER  ACC MC  NLL MC  ECE MC  BRIER MC
# model    M
# Resnet20 100  0.924  0.231  0.005  0.113   0.926   0.228   0.007     0.110
# Resnet32 100  0.932  0.212  0.009  0.100   0.935   0.211   0.007     0.098
# Resnet44 100  0.938  0.201  0.012  0.094   0.940   0.198   0.008     0.092
# Resnet56 100  0.942  0.186  0.011  0.086   0.944   0.183   0.009     0.084
